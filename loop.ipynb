# %%
li=[1,2,3,4,5]
print(li[0])
# Out:
# 1

# %%
li=[1,2,3,4,5]
for i in li:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for elements in range(20,31):
    if elements%2==0:
        print(elements)
# Out:
# 20
# 22
# 24
# 26
# 28
# 30

# %%
for elements in range(20,31,2):
    print(elements)
# Out:
# 20
# 22
# 24
# 26
# 28
# 30

# %%
### while loop

# %%
# may not know ending point but it will be consition base

# %%
# kitne iteration lagane hai then while loop

# %%
a=1
while a<6:
    print(a)
    a+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
### functions

# %%
def random_func():
    print("this is random function")

# %%
random_func()
# Out:
# this is random function

# %%
def add_num():
    a=2+3
    print(a)

# %%
add_num()
# Out:
# 5

# %%
### input to function

# %%
# input to function


def add_two_num(a,b):
    print(f"the sum is {a+b}")

# %%
add_two_num(1,2)
# Out:
# the sum is 3

# %%
def greeting(name):
    print(f"hi {name} good morning")

# %%
greeting("jack")
# Out:
# hi jack good morning

# %%
### output from function

# %%
def add_two_num(a,b):
    print(f"the sum is {a+b}")

# %%
c=add_two_num(5,7)
# Out:
# the sum is 12

# %%
print(c)
# Out:
# None

# %%
def add_two_num(a,b):
    res=a+b
    print(f"the sum is {res}")
    return res

# %%
add_two_num(1,2)
# Out:
# the sum is 3
# 3
