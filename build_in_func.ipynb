# %%
name=['me','you','myself']

# %%
len(name)
# Out:
# 3

# %%
range(len(name))
# Out:
# range(0, 3)

# %%
for i in range(len(name)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(len(name)):
    print(i,name[i])
# Out:
# 0 me
# 1 you
# 2 myself

# %%
for x in enumerate(name):
    print(x)
# Out:
# (0, 'me')
# (1, 'you')
# (2, 'myself')

# %%
for x in enumerate(name,start=1):
    print(x)
# Out:
# (1, 'me')
# (2, 'you')
# (3, 'myself')

# %%
name
# Out:
# ['me', 'you', 'myself']

# %%
colors=['red','blue','yellow']
ages=[23,44,44]

# %%
for abc in zip(name,ages,colors):
    print(abc)
# Out:
# ('me', 23, 'red')
# ('you', 44, 'blue')
# ('myself', 44, 'yellow')
