# %%
import array

# %%
arr1=array.array("i",[10,20,30,40])
print(arr1)
# Out:
# array('i', [10, 20, 30, 40])

# %%
arr1[2]
# Out:
# 30

# %%
arr1[3]
# Out:
# 40

# %%
for i in arr1:
    print(i)
# Out:
# 10
# 20
# 30
# 40

# %%
for i in arr1:
    print(i,end=' ')
# Out:
# 10 20 30 40

# %%
arr1.insert(2,35)

# %%
print(arr1)
# Out:
# array('i', [10, 20, 35, 30, 40])

# %%
arr1.remove(20)
print(arr1)
# Out:
# array('i', [10, 35, 40])

# %%
arr1[2]=90
print(arr1)
# Out:
# array('i', [10, 35, 90])

# %%
sorted(arr1)
print(arr1)
# Out:
# array('i', [10, 35, 90])
