# %%
import array

# %%
arr1=array.array("i",[10,20,30,40])
print(arr1)
# Out:
# array('i', [10, 20, 30, 40])

# %%
arr1[2]
# Out:
# 30

# %%
arr1[3]
# Out:
# 40

# %%
for i in arr1:
    print(i)
# Out:
# 10
# 20
# 30
# 40

# %%
for i in arr1:
    print(i,end=' ')
# Out:
# 10 20 30 40

# %%
arr1.insert(2,35)

# %%
print(arr1)
# Out:
# array('i', [10, 20, 35, 30, 40])

# %%
arr1.remove(20)
print(arr1)
# Out:
# array('i', [10, 35, 40])

# %%
arr1[2]=90
print(arr1)
# Out:
# array('i', [10, 35, 90])

# %%
sorted(arr1)
print(arr1)
# Out:
# array('i', [10, 35, 90])

# %%
### numpy

# %%
! pip install numpy
# Out:
# ...
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# ...

# %%
import numpy as np

# %%
# creation

np1=np.array([10,20,30,40])
np2=np.array([50,60,70])

# %%
for i in np1:
    print(i,end=' ')
# Out:
# 10 20 30 40

# %%
# insertion

np.insert(np1,0,90)
# Out:
# array([90, 10, 20, 30, 40])

# %%
# deletion
np.delete(np1,0)
# Out:
# array([20, 30, 40])

# %%
#sorting
np3=np.array([4,3,6,7,8,9,5,555])

# %%
np3
# Out:
# array([  4,   3,   6,   7,   8,   9,   5, 555])

# %%
np.sort(np3)
# Out:
# array([  3,   4,   5,   6,   7,   8,   9, 555])

# %%
np.array_split(np3,3)
# Out:
# [array([4, 3, 6]), array([7, 8, 9]), array([  5, 555])]
