# %%
a=5
type(a)
# Out:
# int

# %%
a=5.5
type(a)
# Out:
# float

# %%
a=4.
type(a)
# Out:
# float

# %%
a=3+4j
type(a)
# Out:
# complex

# %%
a=0+0j
type(a)
# Out:
# complex

# %%
id(a)
# Out:
# 2442114193712

# %%
s='string'
type(s)
# Out:
# str

# %%
s=str(4)
type(s)
# Out:
# str

# %%
li=[1,2,3,4,5,6,7,'ab',2+5j]
type(li)
# Out:
# list

# %%
tu=(1,2,34,4)
type(tu)
# Out:
# tuple

# %%
t1=5,6,7

# %%
type(t1)
# Out:
# tuple

# %%
z=(6)
type(z)
# Out:
# int

# %%
z=(6,)
type(z)
# Out:
# tuple

# %%
z=6,
type(z)
# Out:
# tuple

# %%
r=range(5)
type(r)
print(list(r))
# Out:
# [0, 1, 2, 3, 4]

# %%
r
# Out:
# range(0, 5)

# %%
### set

# %%
s={1,2,3,4,4}
type(s)
# Out:
# set

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
## froozen set

# %%
s1=frozenset({1,2})
type(s1)
# Out:
# frozenset

# %%
### mapping type

# %%
d={
    'name':'dixitha',
    'age':30
}

# %%
type(d)
# Out:
# dict

# %%
## boolean


a=True
type(a)
# Out:
# bool

# %%
a=None
