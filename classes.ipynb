# %%
class Random:

# %%
class RandomSelection:

# %%
class MyRandomSeletion:
# Out:
#   Cell In[1], line 1
#     class MyRandomSeletion:
#                            ^
# SyntaxError: incomplete input

# %%
class MyRandomClass:
    def __init__(self):
        pass

# %%
class MyRectangle:
    def __init__(self,lenght,width):
        self.lenght=lenght
        self.width=width
        self.random=0

    def get_peri(self):
        return 2*(self.lenght+self.width)

# %%
m=MyRectangle(10,20)
m.get_peri()
# Out:
# 60

# %%
m.random
# Out:
# 0
