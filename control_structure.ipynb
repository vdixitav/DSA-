# %%
a=7
if a>5:
    print("happy")

else:
    print("not happy")
# Out:
# happy

# %%
a=-1
if a>5:
    print("happy")

else:
    print("not happy")
# Out:
# not happy

# %%
a=8

if a%2==0:
    print("even")

else:
    print("odd")
# Out:
# even

# %%
marks=75
if marks>90:
    print("v. good")

elif marks==50:
    print("work hard")

else:
    print("go back to life")
# Out:
# go back to life
